# %%
from ultralytics import YOLO

yolo = YOLO(model="yolo26m.pt", task="deteck")
result = yolo(source="people.jpg", save=True, conf=0.66)
# Out:
# image 1/1 c:\Users\34210\Desktop\yolo\ultralytics-8.4.86\people.jpg: 384x640 2 persons, 3 cars, 3 motorcycles, 314.5ms
# Speed: 4.7ms preprocess, 314.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\34210\Desktop\yolo\ultralytics-8.4.86\runs\detect\predict-4

# %%
display(result[0])
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
